# %% [markdown]
# #### Version's detail (pour qu'on s'y retrouve)
# V2 : Able to parse over wiki page info and turn into csv doc. Strugles with special character and disambiguation pages. Citations counts are weird
#
# V2.1 : Solved the special character problem
#
# V2.2 : Cleaned the table and formated the date. Added a little hist to view page creation along time
#
# V2.3 : Adding a function to pass the 500 treshhold in scraping articles title
#
# V2.4 : Adding the scraping of the titles of sub- and sub-sub-sections

# %%
# !pip install wikipedia setuptools pywikibot mwparserfromhell pandas numpy scipy nltk tqdm seaborn pyqt5 pyqtwebengine ruamel-yaml lxml
# Out:
# Requirement already satisfied: wikipedia in c:\users\aaugr\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: setuptools in c:\users\aaugr\anaconda3\lib\site-packages (62.1.0)
# Requirement already satisfied: pywikibot in c:\users\aaugr\anaconda3\lib\site-packages (6.6.3)
# Requirement already satisfied: mwparserfromhell in c:\users\aaugr\anaconda3\lib\site-packages (0.6.3)
# Requirement already satisfied: pandas in c:\users\aaugr\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy in c:\users\aaugr\anaconda3\lib\site-packages (1.20.3)
# Requirement already satisfied: scipy in c:\users\aaugr\anaconda3\lib\site-packages (1.6.2)
# Requirement already satisfied: nltk in c:\users\aaugr\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: tqdm in c:\users\aaugr\anaconda3\lib\site-packages (4.62.3)
# Requirement already satisfied: seaborn in c:\users\aaugr\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: pyqt5 in c:\users\aaugr\anaconda3\lib\site-packages (5.15.6)
# Requirement already satisfied: pyqtwebengine in c:\users\aaugr\anaconda3\lib\site-packages (5.15.5)
# Requirement already satisfied: ruamel-yaml in c:\users\aaugr\anaconda3\lib\site-packages (0.17.21)
# Requirement already satisfied: lxml in c:\users\aaugr\anaconda3\lib\site-packages (4.6.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\aaugr\anaconda3\lib\site-packages (from wikipedia) (4.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\aaugr\anaconda3\lib\site-packages (from wikipedia) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\aaugr\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\aaugr\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: joblib in c:\users\aaugr\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aaugr\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: click in c:\users\aaugr\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: colorama in c:\users\aaugr\anaconda3\lib\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\aaugr\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\aaugr\anaconda3\lib\site-packages (from pyqt5) (12.9.1)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\aaugr\anaconda3\lib\site-packages (from pyqt5) (5.15.2)
# Requirement already satisfied: PyQtWebEngine-Qt5>=5.15.2 in c:\users\aaugr\anaconda3\lib\site-packages (from pyqtwebengine) (5.15.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in c:\users\aaugr\anaconda3\lib\site-packages (from ruamel-yaml) (0.2.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\aaugr\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aaugr\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aaugr\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aaugr\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: six in c:\users\aaugr\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aaugr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaugr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aaugr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaugr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aaugr\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.2.1)

# %%
import wikipedia
import re
import pywikibot
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
import seaborn as sns
import matplotlib.pyplot as plt
from urllib.request import urlopen
import json

# %%
wikipedia.set_lang("en")  #We make our research in english

# %% [markdown]
# #### definition of the function for the CORPUS SELECTION

# %%
def function_to_get_all_the_bloody_titles(key_words: str) -> list:
    titles = []
    a = key_words.lower().replace(' ', '+')
    scraped_url = 'https://en.wikipedia.org/w/index.php?title=Special:Search&limit=50&offset=0&profile=default&search={}&ns0=1'.format(a)
    html_text = requests.get(scraped_url).text
    soup = BeautifulSoup(html_text, 'lxml')
    r = soup.find('div', {'class' : 'results-info'})
    nbr_result = int(r.get('data-mw-num-results-total'))
    scraped_url2 = 'https://en.wikipedia.org/w/index.php?title=Special:Search&limit={page}&offset=0&profile=default&search={word}&ns0=1'.format(page = nbr_result, word = a)
    html_text2 = requests.get(scraped_url2).text
    soup2 = BeautifulSoup(html_text2, 'lxml')
    for interest in soup2.find_all('div', {'class' : 'mw-search-result-heading'}):
        titles.append(interest.find('a')['title'])
    return titles

# %%
def get_section_titles(page : str) -> list[str]:
    '''
    Returns the section titles

    :param page: Title of the page
    :return: The list of section titles
    '''
    section_tit = set()
    section_title = []
    scraped_url = wikipedia.page(page, auto_suggest = False).url
    html_text = requests.get(scraped_url).text
    soup = BeautifulSoup(html_text, 'lxml')
    r = soup.find_all('h2') + soup.find_all('h3') + soup.find_all('h4')
    for i in r:
        if i.find('span', {'class' : 'mw-headline'}) is not None:
            section_tit.add(i.find('span', {'class' : 'mw-headline'})['id'])
    for i in section_tit:
        section_title.append(i.replace('_', ' '))        
    return section_title

# %%
#We define a function to automatically set up a corpus of related articles
def corpus_selection(word_keys : str , number_of_results, key_for_section) -> list[str]:
    '''
    Select the corpus if the keywords are in the section or in the title

    :param word_keys : string 
    
    :return: a dictionnary containing the title of all the pages of the corpus
    '''
    corpus = []
    s_list = []
    search_list = function_to_get_all_the_bloody_titles(word_keys)[:number_of_results] #Select and put in a list number_of_results wikipedia articles related to word_keys
    a_list = []
    for i in search_list:
        try:
            wikipedia.summary(i, auto_suggest = False)
            a_list.append(i)
        except wikipedia.exceptions.DisambiguationError as e:
            pass
        except wikipedia.exceptions.PageError as e:
            try:
                wikipedia.summary(i, auto_suggest = False)
                a_list.append(i)
            except wikipedia.exceptions.PageError as e:
                pass
    for j in a_list:
        if key_for_section in j.lower(): #Among these articles, select the ones whose title contains key_for_selection for the corpus
            corpus.append(j)
        else:
            s_list.append(j) #Put the rest of the articles in a list
    for k in s_list:
        try :
            sec_tit = get_section_titles(k)
        except wikipedia.exceptions.DisambiguationError as e:
            pass
        except wikipedia.exceptions.PageError as e:
            try:
                sec_tit = get_section_titles(k)
            except wikipedia.exceptions.PageError as e:
                pass
        for l in sec_tit:
            if key_for_section.replace(' ', '_').lower() in l.lower() and k not in corpus:
                corpus.append(k)
    return corpus

# %% [markdown]
# ## TO LAUNCH THE CORPUS SELECTION

# %%
# %%time
search_list = corpus_selection("Effects of climate change", 5000, 'climate change')
# Out:
# Wall time: 43min 1s

# %%
search_list=["Effects of climate change","Climate change", "Bird migration","Climate change in Alabama","Climate change in California","Climate change in Arizona"]

# %%
len(set(search_list))#gives us the number of article in our corpus
# Out:
# 924

# %%
set(search_list)#gives us the title of our corpus
# Out:
# {'2008 United Nations Climate Change Conference',
#  '2009 United Nations Climate Change Conference',
#  '2010s oil glut',
#  '2011 United Nations Climate Change Conference',
#  '2012 United Nations Climate Change Conference',
#  '2013 United Nations Climate Change Conference',
#  '2014 United Nations Climate Change Conference',
#  '2015 Commonwealth Heads of Government Meeting',
#  '2015 United Nations Climate Change Conference',
#  '2016 Louisiana floods',
#  '2016 Pakistan Floods',
#  '2016 United Nations Climate Change Conference',
#  '2018 United Nations Climate Change Conference',
#  '2019 in climate change',
#  '2019 mass invasion of Russian polar bears',
#  '2019–20 Australian bushfire season',
#  '2020 California wildfires',
#  '2020 Western United States wildfire season',
#  '2020 in climate change',
#  '2020s in environmental history',
#  '2021 European floods',
#  '2021 Maharashtra floods',
#  '2021 United Nations Climate Change Conference',
#  '2021 Western North America heat wave',
#  '2021 in climate change',
#  '2021–2022 Malaysian floods',
#  '2022 in climate change',
#  '55th Munich Security Conference',
#  'ACT New Zealand',
#  'Abaiang',
#  'Abrupt climate change',
#  'Accuracy in Media',
#  'Affect heuristic',
#  'Africa',
#  'Agriculture',
#  'Agriculture in Bangladesh',
#  'Agriculture in Moldova',
#  'Agriculture in Thailand',
#  'Agriculture in the Philippines',
#  'Agriculture in the United States',
#  'Agulhas Leakage',
#  'Air pollution in Germany',
#  'Air pollution in Turkey',
#  'Alaska Current',
#  'Alaska Natives',
#  'Alpine skiing',
#  'Alpine vegetation of Tasmania',
#  'Altitudinal migration',
#  'Amazon Reef',
#  'Amazon basin',
#  'Amazon rainforest',
#  'Amelia Earhart Dam',
#  'American Coalition for Clean Coal Electricity',
#  'American Farm Bureau Federation',
#  'American Samoa',
#  'Andean agriculture',
#  'Andrew Bolt',
#  'Andrew Dessler',
#  'Anote Tong',
#  'Antarctic Peninsula',
#  'Antarctic bottom water',
#  'Antarctic sea ice',
#  'Antarctica',
#  'Anthony Costello',
#  'Anthony Watts (blogger)',
#  'Apalachicola Bay',
#  'Aquaculture in South Korea',
#  'Arbuscular mycorrhiza',
#  'Arctic National Wildlife Refuge',
#  'Arctic methane emissions',
#  'Arctic resources race',
#  'Asylum in the United States',
#  'Atlantic hurricane',
#  'Atlantic puffin',
#  'Attribution of recent climate change',
#  'Australian Conservation Foundation',
#  'Avalanche',
#  'Avoiding Dangerous Climate Change (2005 conference)',
#  'Bactrocera tryoni',
#  'Badlands National Park',
#  'Banksia cuneata',
#  'Barren-ground caribou',
#  'Benin City',
#  'Benthic-pelagic coupling',
#  'Bernie Sanders',
#  'Bio-geoengineering',
#  'Biodegradable waste',
#  'Biodiversity',
#  'Biodiversity loss',
#  'Biodiversity of South Africa',
#  'Biogeomorphology',
#  'Biosequestration',
#  'Bird migration',
#  'Bird migration perils',
#  'Bolivia',
#  'Bombus balteatus',
#  'Boreal ecosystem',
#  'Boundary current',
#  'Brine rejection',
#  'Brown planthopper',
#  'Buff-sided robin',
#  'Bury the Chains',
#  'Bushfires in Australia',
#  'CCS and climate change mitigation',
#  'Canadian Arctic tundra',
#  'Canadian Environmental Sustainability Indicators',
#  'Canadian Northern Economic Development Agency',
#  'Canyonlands National Park',
#  'Carbon Disclosure Project',
#  'Carbon cycle',
#  'Carbon sequestration',
#  'Caribbean',
#  'Carl Wunsch',
#  'Carol Browner',
#  'Cat flea',
#  'Causes of poverty',
#  'Cellana exarata',
#  'Center for International Forestry Research',
#  'Centre for Aviation, Transport and Environment',
#  'Centre for Social Research',
#  'Chesapeake Bay',
#  'Chicago Wilderness',
#  'Child',
#  'China Price',
#  'Chris Huhne',
#  'Chytridiomycosis',
#  'City',
#  'Climate',
#  'Climate Change Denial',
#  'Climate Change Denial Disorder',
#  'Climate Change Response (Emissions Trading) Amendment Act 2008',
#  'Climate Change Response Act 2002',
#  'Climate Change Science Program',
#  'Climate Change TV',
#  'Climate Change: Global Risks, Challenges and Decisions',
#  'Climate and Development Knowledge Network',
#  'Climate and vegetation interactions in the Arctic',
#  'Climate apocalypse',
#  'Climate change',
#  'Climate change adaptation',
#  'Climate change adaptation strategies on the German coast',
#  'Climate change and agriculture in the United States',
#  'Climate change and birds',
#  'Climate change and children',
#  'Climate change and cities',
#  'Climate change and fisheries',
#  'Climate change and gender',
#  'Climate change and indigenous peoples',
#  'Climate change and infectious diseases',
#  'Climate change and invasive species',
#  'Climate change and poverty',
#  'Climate change art',
#  'Climate change denial',
#  'Climate change feedback',
#  'Climate change in Africa',
#  'Climate change in Alabama',
#  'Climate change in Alaska',
#  'Climate change in Algeria',
#  'Climate change in American Samoa',
#  'Climate change in Antarctica',
#  'Climate change in Argentina',
#  'Climate change in Arizona',
#  'Climate change in Arkansas',
#  'Climate change in Australia',
#  'Climate change in Austria',
#  'Climate change in Bangladesh',
#  'Climate change in Belgium',
#  'Climate change in Brazil',
#  'Climate change in California',
#  'Climate change in Cambodia',
#  'Climate change in Canada',
#  'Climate change in China',
#  'Climate change in Colorado',
#  'Climate change in Connecticut',
#  'Climate change in Cyprus',
#  'Climate change in Delaware',
#  'Climate change in Europe',
#  'Climate change in Fiji',
#  'Climate change in Finland',
#  'Climate change in Florida',
#  'Climate change in France',
#  'Climate change in Georgia (U.S. state)',
#  'Climate change in Germany',
#  'Climate change in Greenland',
#  'Climate change in Grenada',
#  'Climate change in Guam',
#  'Climate change in Guatemala',
#  'Climate change in Honduras',
#  'Climate change in Idaho',
#  'Climate change in Illinois',
#  'Climate change in India',
#  'Climate change in Indiana',
#  'Climate change in Indonesia',
#  'Climate change in Iowa',
#  'Climate change in Iraq',
#  'Climate change in Israel',
#  'Climate change in Japan',
#  'Climate change in Kansas',
#  'Climate change in Kentucky',
#  'Climate change in Kenya',
#  'Climate change in Kyrgyzstan',
#  'Climate change in Liberia',
#  'Climate change in Louisiana',
#  'Climate change in Maine',
#  'Climate change in Malaysia',
#  'Climate change in Maryland',
#  'Climate change in Massachusetts',
#  'Climate change in Mexico',
#  'Climate change in Michigan',
#  'Climate change in Minnesota',
#  'Climate change in Mississippi',
#  'Climate change in Missouri',
#  'Climate change in Montana',
#  'Climate change in Morocco',
#  'Climate change in Nebraska',
#  'Climate change in Nepal',
#  'Climate change in Nevada',
#  'Climate change in New Hampshire',
#  'Climate change in New Jersey',
#  'Climate change in New Mexico',
#  'Climate change in New York (state)',
#  'Climate change in New York City',
#  'Climate change in New Zealand',
#  'Climate change in Nigeria',
#  'Climate change in North Dakota',
#  'Climate change in North Korea',
#  'Climate change in Norway',
#  'Climate change in Ohio',
#  'Climate change in Oklahoma',
#  'Climate change in Oregon',
#  'Climate change in Pakistan',
#  'Climate change in Pennsylvania',
#  'Climate change in Puerto Rico',
#  'Climate change in Rhode Island',
#  'Climate change in Russia',
#  'Climate change in Saskatchewan',
#  'Climate change in Scotland',
#  'Climate change in Senegal',
#  'Climate change in South Africa',
#  'Climate change in South Asia',
#  'Climate change in South Carolina',
#  'Climate change in South Dakota',
#  'Climate change in Spain',
#  'Climate change in Sri Lanka',
#  'Climate change in Suriname',
#  'Climate change in Sweden',
#  'Climate change in Taiwan',
#  'Climate change in Tanzania',
#  'Climate change in Tennessee',
#  'Climate change in Texas',
#  'Climate change in Thailand',
#  'Climate change in Turkey',
#  'Climate change in Tuvalu',
#  'Climate change in Uganda',
#  'Climate change in Utah',
#  'Climate change in Vermont',
#  'Climate change in Vietnam',
#  'Climate change in Virginia',
#  'Climate change in Washington (state)',
#  'Climate change in West Virginia',
#  'Climate change in Wisconsin',
#  'Climate change in Wyoming',
#  'Climate change in popular culture',
#  'Climate change in the Arctic',
#  'Climate change in the Caribbean',
#  'Climate change in the Middle East and North Africa',
#  'Climate change in the Philippines',
#  'Climate change in the Republic of Ireland',
#  'Climate change in the United Kingdom',
#  'Climate change in the United States',
#  'Climate change litigation and the California Environmental Quality Act',
#  'Climate change mitigation',
#  'Climate change mitigation framework',
#  'Climate change policy of California',
#  'Climate change policy of the United States',
#  'Climate change scenario',
#  'Climate change vulnerability',
#  'Climate ethics',
#  'Climate finance',
#  'Climate of Africa',
#  'Climate of Anchorage',
#  'Climate of Antarctica',
#  'Climate of Argentina',
#  'Climate of Australia',
#  'Climate of Ecuador',
#  'Climate of Europe',
#  'Climate of Georgia (U.S. state)',
#  'Climate of India',
#  'Climate of Italy',
#  'Climate of Minnesota',
#  'Climate of Myanmar',
#  'Climate of New York City',
#  'Climate of Pakistan',
#  'Climate of Seattle',
#  'Climate of South Africa',
#  'Climate of South Carolina',
#  'Climate of Spain',
#  'Climate of Svalbard',
#  'Climate of Vietnam',
#  'Climate of Virginia',
#  'Climate of the United Kingdom',
#  'Climate psychology',
#  'Climate resilience',
#  'Climate sensitivity',
#  'Climate variability and change',
#  'Climateprediction.net',
#  'Climatic Research Unit email controversy',
#  'Cloud',
#  'Cloud forest',
#  'Cloud formation and climate change',
#  'Co-benefits of climate change mitigation',
#  'Coal',
#  'Coal in Europe',
#  'Coast',
#  'Coccolithophore',
#  'Colony collapse disorder',
#  'Colorado',
#  'Community resilience',
#  'Conservation in Papua New Guinea',
#  'Contemporary history',
#  'Copenhagen Consensus',
#  'Coral Reef Conservation Program',
#  'Coral in non-tropical regions',
#  'Cosmic ray',
#  'Craig Kelly',
#  'Critical realism (philosophy of the social sciences)',
#  'Culture of Greenland',
#  'Cupido carswelli',
#  'Cyanobacteria',
#  'Dave Lowe (atmospheric scientist)',
#  'David Legates',
#  'David Suzuki',
#  'David Wratt',
#  "Debate over China's economic responsibilities for climate change mitigation",
#  'Deep energy retrofit',
#  'Deforestation and climate change',
#  'Deforestation in Brazil',
#  'Deforestation in Thailand',
#  'Deforestation in the Democratic Republic of the Congo',
#  'Degrowth',
#  'Denialism',
#  'Dennis T. Avery',
#  'Developing country',
#  'Development of skiing in Utah',
#  'Diprotodon',
#  'Dipterocarpaceae',
#  'Disability and climate change',
#  'Disaster risk reduction',
#  'Disease ecology',
#  'Domestic policy of the Justin Trudeau government',
#  'Drainage density',
#  'Drought',
#  'Droughts in California',
#  'Drunken trees',
#  'Dystrophic lake',
#  "Earth's energy budget",
#  'East Asia Climate Partnership',
#  'Ecocide',
#  'Ecological crisis',
#  'Ecological evolutionary developmental biology',
#  'Ecological extinction',
#  'Ecological resilience',
#  'Ecology of Florida',
#  'Economic impacts of climate change',
#  'Economic policy of the Donald Trump administration',
#  'Economics of climate change',
#  'Economics of climate change mitigation',
#  'Economy of Tuvalu',
#  'Ecosystem-based adaptation',
#  'Ectomycorrhiza',
#  'Ed Davey',
#  'Education in emergencies and conflict areas',
#  'Effects of Hurricane Harvey in Texas',
#  'Effects of climate change',
#  'Effects of climate change on agriculture',
#  'Effects of climate change on ecosystems',
#  'Effects of climate change on human health',
#  'Effects of climate change on island nations',
#  'Effects of climate change on mental health',
#  'Effects of climate change on oceans',
#  'Effects of climate change on plant biodiversity',
#  'Effects of climate change on terrestrial animals',
#  'Effects of climate change on the water cycle',
#  'Electricity sector in Mexico',
#  'Emiliania huxleyi',
#  'Emily Ying Yang Chan',
#  'Enele Sopoaga',
#  'Energy in Australia',
#  'Energy policy of Russia',
#  'Energy poverty',
#  'Environment of Australia',
#  'Environment of China',
#  'Environment of Florida',
#  'Environment of India',
#  'Environment of Indonesia',
#  'Environment of Tennessee',
#  'Environment of the United States',
#  'Environmental communication',
#  'Environmental degradation',
#  'Environmental disaster',
#  'Environmental effects of aviation',
#  'Environmental governance',
#  'Environmental governance in Brazil',
#  'Environmental gradient',
#  'Environmental impact of agriculture',
#  'Environmental impact of concrete',
#  'Environmental impact of hydraulic fracturing',
#  'Environmental impact of the energy industry',
#  'Environmental impact of the petroleum industry',
#  'Environmental impact of wind power',
#  'Environmental issues in Africa',
#  'Environmental issues in Australia',
#  'Environmental issues in Brazil',
#  'Environmental issues in Canada',
#  'Environmental issues in China',
#  'Environmental issues in Florida',
#  'Environmental issues in Georgia (country)',
#  'Environmental issues in Haiti',
#  'Environmental issues in Israel',
#  'Environmental issues in Kuwait',
#  'Environmental issues in Liberia',
#  'Environmental issues in Melbourne',
#  'Environmental issues in Mongolia',
#  'Environmental issues in Nepal',
#  'Environmental issues in Pakistan',
#  'Environmental issues in Senegal',
#  'Environmental issues in Sri Lanka',
#  'Environmental issues in Thailand',
#  'Environmental issues in the European Union',
#  'Environmental issues in the Philippines',
#  'Environmental issues in the United Arab Emirates',
#  'Environmental issues in the United Kingdom',
#  'Environmental issues in the United States',
#  'Environmental issues with coral reefs',
#  'Environmental issues with salmon',
#  'Environmental justice',
#  'Environmental policy of the Donald Trump administration',
#  'Environmental policy of the Joe Biden administration',
#  'Environmental threats to the Great Barrier Reef',
#  'Escarpment Mine Project',
#  'European Bank for Reconstruction and Development',
#  'European Climate Change Programme',
#  'European Investment Bank',
#  'European corn borer',
#  'Evan Bayh',
#  'Externalities of automobiles',
#  'Extinction',
#  'Extinction risk from climate change',
#  'Extreme weather',
#  'ExxonMobil',
#  'ExxonMobil climate change controversy',
#  'False balance',
#  'Farmworker',
#  'Feminization of poverty',
#  'Fertilizer',
#  'Fiji and the United Nations',
#  'Fire regime',
#  'Fisheries management',
#  'Fishery',
#  'Flood',
#  'Flood control',
#  'Florida mangroves',
#  'Food security',
#  'Food system',
#  'Forest dieback',
#  'Forest dynamics',
#  'Forest migration',
#  'Fossil Fuel Beta',
#  'Fossil fuel phase-out',
#  'Fox News',
#  'Fragile state',
#  'France and the United Nations',
#  'Freeman Dyson',
#  'Freshwater shoreline management',
#  'Future-proof',
#  'G8 Climate Change Roundtable',
#  'Galapagos penguin',
#  'Ganges',
#  'Garden',
#  'Garnaut Climate Change Review',
#  'Gender',
#  'Gene-for-gene interactions in rust fungi',
#  'General Grant Grove',
#  'Geography of Bangladesh',
#  'Geography of China',
#  'Geography of Georgia (U.S. state)',
#  'Geography of Greenland',
#  'Geography of Guatemala',
#  'Geography of Honduras',
#  'Geography of Kenya',
#  'Geography of Kyrgyzstan',
#  'Geography of Liberia',
#  'Geography of Malaysia',
#  'Geography of Morocco',
#  'Geography of North Korea',
#  'Geography of South Africa',
#  'Geography of Tibet',
#  'Geography of Tuvalu',
#  'Geography of Vietnam',
#  'Geography of Western Australia',
#  'Geopolitics of the Arctic',
#  'George Monbiot',
#  'Giant Pacific octopus',
#  'Glacial stream',
#  'Glacier',
#  'Global Hunger Index',
#  'Global catastrophe scenarios',
#  'Global warming game',
#  'Glossary of climate change',
#  'Goddard Institute for Space Studies',
#  'Gopher tortoise',
#  'Gordon J. F. MacDonald',
#  'Grand Canyon',
#  'Grassland',
#  'Grassland degradation',
#  'Great Barrier Reef',
#  'Great Green Wall (China)',
#  'Great Lakes',
#  'Great Plains ecoregion',
#  'Green job',
#  'Greenhouse effect',
#  'Greenhouse gas emissions by Australia',
#  'Greenhouse gas emissions by China',
#  'Greta Thunberg',
#  'Ground level ozone',
#  'Groundwater recharge',
#  'Harbour porpoise',
#  'Hardiness zone',
#  'Harmful algal bloom',
#  'Harold Lewis',
#  'Health in Nigeria',
#  'Health in the United States',
#  'Heartland Institute',
#  'Heat wave',
#  'Henrik Svensmark',
#  'Historical climatology',
#  'History of Tuvalu',
#  'History of climate change science',
#  'Holocene extinction',
#  'Hubert Lamb',
#  'Hudson Plains Ecoregion',
#  'Human impact on marine life',
#  'Human impact on the environment',
#  'Human rights and climate change',
#  'Human rights in Ireland',
#  'Human sex ratio',
#  'Hunger in Bangladesh',
#  'Hurricane Harvey',
#  'Hurricane Ophelia (2017)',
#  'IPCC Fifth Assessment Report',
#  'IPCC Fourth Assessment Report',
#  'IPCC Second Assessment Report',
#  'IPCC Sixth Assessment Report',
#  'Ian Plimer',
#  'Ice algae',
#  'Ice shove',
#  'Ice-sheet dynamics',
#  'Illustrative model of greenhouse effect on climate change',
#  'Impact of the COVID-19 pandemic on the environment',
#  'Index of climate change articles',
#  'Indigenous Peoples Climate Change Assessment Initiative',
#  'Individual action on climate change',
#  'Induced innovation',
#  'Indur M. Goklany',
#  'Indus River',
#  'Inland rainforest',
#  'Institute for Environmental Policy in Albania',
#  'Institute of Atmospheric Physics AS CR',
#  'Intergovernmental Panel on Climate Change',
#  'International Food Policy Research Institute',
#  'International Socialist Alternative',
#  'International relations since 1989',
#  'Inuit Nunangat',
#  'Invasive species in the United States',
#  'Iron-oxidizing bacteria',
#  'Irrigation in Peru',
#  'Irrigation in Vietnam',
#  'Island country',
#  'Istanbul',
#  'J. Scott Armstrong',
#  'Jacob Rees-Mogg',
#  'James Hansen',
#  'Jay Inslee 2020 presidential campaign',
#  'Jeff Merkley',
#  'Jim Inhofe',
#  'Jim Mattis',
#  'Joanna Haigh',
#  'John Gribbin',
#  'Jordan Peterson',
#  'Josephine Staton',
#  'Judith Curry',
#  'Jungle Nama',
#  'K. A. Colorado',
#  'K. Madhava Sarma',
#  'Ken Caldeira',
#  'Kim Stanley Robinson',
#  'King penguin',
#  'Kuroshio Current',
#  'Kyrgyzstan',
#  'Köppen climate classification',
#  'Labor and the environment',
#  'Lake Superior',
#  'Land clearing in Australia',
#  'Land degradation',
#  'Landfill gas emission reduction in Brazil',
#  'Late Triassic',
#  "Laudato si'",
#  'Laurie David',
#  'Lessepsian migration',
#  'Liberia',
#  'Lightning',
#  'Lipid pump',
#  'Lise Van Susteren',
#  'List of climate change books',
#  'List of ecoregions in North America (CEC)',
#  'List of environmental websites',
#  'List of parties to the United Nations Framework Convention on Climate Change',
#  'Loss and damage',
#  'Louie Gohmert',
#  'Lumad',
#  'Lynedoch, Ontario',
#  'Madden–Julian oscillation',
#  'Madhya Pradesh Rural Livelihoods Project',
#  'Maharashtra floods of 2005',
#  'Malaria',
#  'Maldives and the World Bank',
#  'Mammoth steppe',
#  'Managed retreat',
#  'Mangrove restoration',
#  'Mangrove tree distribution',
#  'Manitoba Eco-Network',
#  'Marine ecosystem',
#  'Mark C. Urban',
#  'Marsh organ',
#  'Marsha Blackburn',
#  'Marsupial lawn',
#  'Massachusetts',
#  'Mast (botany)',
#  'Meadow',
#  'Meat',
#  'Media coverage of climate change',
#  'Mediterranean Sea',
#  'Mehmet Oz',
#  'Meroplankton',
#  'Mesopelagic zone',
#  'Mesopotamian Marshes',
#  'Methane clathrate',
#  'Micha Tomkiewicz',
#  'Michael Greenstone',
#  'Michael R. Rampino',
#  'Microbiology of oxygen minimum zones',
#  'Migration studies',
#  'Mindanao',
#  'Mindanao Current',
#  'Ministry of Environment and Parks',
#  'Mississippi',
#  'Mitchell Taylor',
#  'Mixotrophic dinoflagellate',
#  'Monomictic lake',
#  'Monsoon of South Asia',
#  'Mont Blanc',
#  'Morrison government',
#  'Munich',
#  'Myanmar',
#  'Mycorrhiza',
#  'Mycorrhizae and climate change',
#  'Māui dolphin',
#  'NOOR photo agency',
#  'National Climate Change Secretariat',
#  'National Flood Insurance Program',
#  'National Oceanic and Atmospheric Administration',
#  'Natural disasters in India',
#  'Nature Climate Change',
#  'Neanderthal extinction',
#  'Neo-colonial science',
#  'New York (state)',
#  'New Zealand Emissions Trading Scheme',
#  'Nir Shaviv',
#  'Niskanen Center',
#  'Nordic Genetic Resource Center',
#  'North American Arctic',
#  'North American inland temperate rainforest',
#  'North Atlantic right whale',
#  'North Indian Ocean tropical cyclone',
#  'Norwegian Current',
#  'Ocean',
#  'Ocean chemistry',
#  'Ocean colonization',
#  'Ocean deoxygenation',
#  'Ocean dynamical thermostat',
#  'Ocean gyre',
#  'Oceanic freshwater flux',
#  'Ozone depletion and climate change',
#  'PTAA GMB Model',
#  'Pacific Meridional Mode',
#  'Pacific Remote Islands Marine National Monument',
#  'Pack rat',
#  'Pagophily',
#  'Paleocene–Eocene Thermal Maximum',
#  'Paleoflooding',
#  'Paleolimnology',
#  'Palsa',
#  'Pan-Canadian Framework on Clean Growth and Climate Change',
#  'Pangaea',
#  'Patrick Moore (consultant)',
#  "Pauline Hanson's One Nation",
#  'Peabody Energy',
#  'Peak water',
#  'Peel watershed',
#  "People's Archive of Rural India",
#  'Permafrost',
#  'Pest insect population dynamics',
#  'Petroleum',
#  'Petroleum industry in Western Australia',
#  'Phenotypic plasticity',
#  'Pingo',
#  'Pink noise',
#  'Piping plover',
#  'PlaNYC',
#  'Planetary boundaries',
#  'Planktivore',
#  'Plastic',
#  'Plastic pollution',
#  'Polar bear',
#  'Polar vortex',
#  'Political activities of the Koch brothers',
#  'Political impact of Hurricane Sandy',
#  'Political positions of Donald Trump',
#  'Political positions of Ted Cruz',
#  'Politics of climate change',
#  'Pollution in Canada',
#  'Polygonia c-album',
#  'Port',
#  'Potato',
#  'Poverty in Africa',
#  'Poverty in the Arctic',
#  'Poverty reduction',
#  'Presidency of Barack Obama',
#  'Privet as an invasive plant',
#  'Psychological impact of climate change',
#  'Psychology of climate change denial',
#  'Public opinion on climate change',
#  'Puerto Rico',
#  'Pygmy mammoth',
#  'Quantitative easing',
#  'Quaternary extinction event',
#  'Rafe Pomerance',
#  'Rat snake',
#  'Reducing emissions from deforestation and forest degradation',
#  'Reforestation',
#  'Refugium (population biology)',
#  'Regulation S-K',
#  'Regulation of greenhouse gases under the Clean Air Act',
#  'Renewable energy in Tuvalu',
#  'Reservoir',
#  'Resource Management Act 1991',
#  'Rewilding (conservation biology)',
#  'Rhodolith',
#  'Rice',
#  'Richard A. Muller',
#  'Richard Lindzen',
#  'Richard Tol',
#  'Ringed seal',
#  'Rio Convention',
#  'Ro Khanna',
#  'Rocky Mountain National Park',
#  'Rocky Mountain elk',
#  'Roger Revelle',
#  'Ron Wyden',
#  'Ross Garnaut',
#  'Ruminant',
#  'Sable Island',
#  'Salinity in Australia',
#  'Sanitary engineering',
#  'Sanitation',
#  'Sargassum',
#  'Saskatchewan',
#  'Savanna',
#  'Scientific consensus on climate change',
#  'Scophthalmidae',
#  'Scottish Environment Protection Agency',
#  'Sea ice',
#  'Sea turtle',
#  'Seven Springs, North Carolina',
#  'Shade-grown coffee',
#  'Shale gas in the United Kingdom',
#  'Shell plc',
#  'Shenandoah salamander',
#  'Sierra Nevada subalpine zone',
#  'Sinking cities',
#  'Small Island Developing States',
#  'Snow bunting',
#  'Social discount rate',
#  'Social trap',
#  'Societal collapse',
#  'Soft climate change denial',
#  'Soil carbon feedback',
#  'Soil erosion',
#  'Soil regeneration',
#  'Soil respiration',
#  'Solomon Hsiang',
#  'South Carolina',
#  'South Park controversies',
#  'Southern Australia',
#  'Southern Ocean',
#  'Southwestern North American megadrought',
#  'Space mirror (climate engineering)',
#  'Special Report on Climate Change and Land',
#  'Special Report on Emissions Scenarios',
#  'Spectacle case pearly mussel',
#  'Stephan Lewandowsky',
#  'Stern Review',
#  'Stoma',
#  'Storm Water Management Model',
#  'Subantarctic',
#  'Subsistence agriculture',
#  'Sundarbans',
#  'Surf break',
#  'Surface water',
#  "Surveys of scientists' views on climate change",
#  'Susie Wood',
#  'Sustainable Development Goal 13',
#  'Sustainable Urban Development Network',
#  'Sustainable design',
#  'Sustainable fishery',
#  'Symphony of Science',
#  'Synchronous flowering',
#  'Syringodium filiforme',
#  'Taiga',
#  'Tammy Baldwin',
#  "Tanzania's food security",
#  'Technological fix',
#  'Temperature-dependent sex determination',
#  'Tessa M. Hill',
#  'The Earth Institute',
#  'The General Crisis',
#  'The Wall Street Journal',
#  'The Washington Times',
#  'Thermal ecology',
#  'Third Pole',
#  'Thom Yorke',
#  'Thoughts and prayers',
#  'Tibetan Plateau',
#  'Tidal flooding',
#  'Tidewater glacier cycle',
#  'Tim Flannery',
#  'Tim Kaine',
#  'Tina Smith',
#  'Tony Abbott',
#  'Tornado',
#  'Torres Strait Islands',
#  'Torreya Guardians',
#  'Totoya',
#  'Tourism in Latvia',
#  'Tourism in Zanzibar',
#  'Toxoplasmosis',
#  'Traditional ecological knowledge',
#  'Tragedy of the commons',
#  'Tree planting',
#  'Tropical agriculture',
#  'Tropical cyclone',
#  'Tropical cyclones and climate change',
#  'Tropical rain belt',
#  'Tropical rainforest',
#  'Tuvalu',
#  'Tuvalu–United States relations',
#  'Typhoon Haiyan',
#  'UK Health Alliance on Climate Change',
#  'UNDP South Africa',
#  'Umm al Binni lake',
#  'United Nations Climate Change conference',
#  'United Nations Framework Convention on Climate Change',
#  'United States Environmental Protection Agency',
#  'Urban climatology',
#  'Urban flooding',
#  'Urban forestry',
#  'Urban heat island',
#  'Urban planning in Australia',
#  'Urban resilience',
#  'Vanessa atalanta',
#  'Vermont',
#  'Victoria Falls',
#  'Vulnerability',
#  'Václav Klaus',
#  'WASH',
#  'Walter Orr Roberts',
#  'Water cycle',
#  'Water in California',
#  'Water resources',
#  'Water resources management in Argentina',
#  'Water resources management in Bolivia',
#  'Water resources management in El Salvador',
#  'Water resources management in Peru',
#  'Water scarcity',
#  'Water scarcity in Africa',
#  'Water scarcity in India',
#  'Water security',
#  'Water supply and sanitation in the United States',
#  'Waterborne disease and climate change',
#  'Weather and climate effects on Lyme disease exposure',
#  'West Africa',
#  'West Nile virus',
#  'Wetland',
#  'White band disease',
#  'White-rumped sandpiper',
#  'White-tailed deer',
#  'Wildfire',
#  'Wildlife conservation',
#  'Wildlife observation',
#  'Women and the environment',
#  'Women in climate change',
#  'Wood industry',
#  'Woody plant encroachment',
#  'World Bank',
#  'World Health Day',
#  "World Scientists' Warning to Humanity",
#  'World Water Day',
#  'Xiuhtezcatl Martinez',
#  'Younger Dryas',
#  'Zanzibar',
#  'Zoonosis'}

# %% [markdown]
# #### definition of the function for the extraction of citation

# %%
# Some additional functions
def get_ids_from_ref(ref):
    d = dict(re.findall(r'(doi|pmc|pmid)\s?[=\|]\s?([^|\s}]*)', ref))
    ids = {k: v for k, v in d.items() if v}
    return ids

        
def get_citations(wikicode):
    citations = [c.lower() for c in re.findall(r'<ref(?:\s(?:[^\/]*?))?>(.*?)<\/ref>', wikicode) + re.findall(r'({{(?:cite|vcite2|Cite)\s[^}]*}})', wikicode)]
    s = set()
    
    i=0
    for c in citations:
        i+=1
        #print("beginning of c",i,c,"end of c")
        s.update(c.split('<br/>'))
        
    ds = pd.DataFrame(s, columns=['ref'])
    
   
    ds['ids'] = ds['ref'].apply(get_ids_from_ref)
    ds['pmid'] = ds['ids'].apply(lambda x: x.get('pmid', None))
    ds['doi'] = ds['ids'].apply(lambda x: x.get('doi', None))
    ds['pmc'] = ds['ids'].apply(lambda x: x.get('pmc', None))
    ds["available"]=ds["ids"]== {}
    
    
    dsbis= ds[(~ds['pmid'].isnull())|~(ds['doi'].isnull())|~(ds['pmc'].isnull())]
    
    ds = ds[(~ds['pmid'].duplicated()) | (ds['pmid'].isnull())]
    ds = ds[(~ds['doi'].duplicated()) | (ds['doi'].isnull())]
    ds = ds[(~ds['pmc'].duplicated()) | (ds['pmc'].isnull())]


    dg=ds.loc[ds["available"]==True,["ref"]]
    dg['ids']=dg['ref'].apply(get_IPCC_guardian_ipbes_from_ref)
    dg['IPCC'] = dg['ids'].apply(lambda x: x.get('IPCC', None))
    dg['ipbes'] = dg['ids'].apply(lambda x: x.get('ipbes', None))
    dg['guard'] = dg['ids'].apply(lambda x: x.get('guardian', None))
    dg["available"]= dg["ids"]=={}
    
    
    
    dcit=dg.loc[dg["available"]==True,["ref"]]
    dcit['ids'] = dcit['ref'].apply(get_cit_from_ref)
    dcit['org'] = dcit['ids'].apply(lambda x: x.get('org', None))
    dcit['gov'] = dcit['ids'].apply(lambda x: x.get('gov', None))
    dcit['com'] = dcit['ids'].apply(lambda x: x.get('com', None))
    dcit["available"]= dcit["ids"]=={}
    
    #creation of a data frame with all the other type of citation that weren't extracted
    drest = dcit.loc[dcit["available"]==True,["ref"]]
    print(drest)
    
    dgbisgov=dcit[(~dcit['gov'].isnull())]
    
    dgbisorg=dcit[(~dcit['org'].isnull())]
    
    dgbisIPCC=dg[(~dg['IPCC'].isnull())]
    
    dgbiscom=dcit[(~dcit['com'].isnull())]
    
    
    return {'Ref count': ds.shape[0], 'nb_journal_citations': ds[(~ds['pmid'].isnull()) | (~ds['doi'].isnull()) | (~ds['pmc'].isnull())].shape[0],"citationjournal":list(list(dsbis["doi"])+list(dsbis["pmid"])+list(dsbis["pmc"])),"citations.org": dcit[(~dcit['org'].isnull())].shape[0],"citations.gov": dcit[(~dcit['gov'].isnull())].shape[0],"citationgovtext":list(dgbisgov['gov']),"citationorgtext":list(dgbisorg['org']),"citationsIPCC.ch": dg[(~dg['IPCC'].isnull())].shape[0],"citationautre":list(drest["ref"]),"citationcomtext":list(dgbiscom['com']),"citations.com": dcit[(~dcit['com'].isnull())].shape[0],"citationsipbes": dg[(~dg['ipbes'].isnull())].shape[0],"citationguardian": dg[(~dg['guard'].isnull())].shape[0]}

# %%
def get_cit_from_ref(ref):
    d = dict(re.findall(r"((?:[(?:\.)(?:\-)\w]*)\.(org|com|gov))", ref, flags=re.IGNORECASE))
    
    if 'web.archive.org' in d:
        d.pop('web.archive.org', None)
        #d.remove('web.archive.org') 
    ids = {v: k for k, v in d.items() if v}
    
    return ids

# %%
def get_IPCC_guardian_ipbes_from_ref(ref):
    g={}
    citation=list(set(re.findall(r"(ipcc|ipbes|guardian)", ref, flags=re.IGNORECASE)))
    if citation !=None and citation !=[]:
        if "ipcc" in citation:
            g["IPCC"]=citation
        if "ipbes" in citation:
            g["ipbes"]=citation
        if "guardian" in citation:
            g["guardian"]=citation
        return g
    else:
        return{}

# %% [markdown]
# #### creation du dataframe

# %%
# %%time
def crea_dataframe(search_list : list,keyword : str)-> pd.DataFrame:
    '''
    param search_list: liste containing the name of all the articles
    param keyword: string containing the keyword that we want to scrap
    
    
    return: data frame containg the name, the url and the wikicode of the entire page if the keyword is in the title.
    If it's not it returns the wiki code of the section containing the keyword only.  
    '''
    tableau =[] #creation of a list that will contain a dictionnary for each page with the information
    recode= r'(?:==(?:\w|\ )*?(?:'+keyword[0].lower()+'|'+keyword[0].upper()+')'+keyword[1:]+'(?:\w|\ )*?==\n)((?:.|\n)*?)(?:==(?:\w|\ )*==\n)'
    recode2=r'(?:===(?:\w|\ )*?(?:'+keyword[0].lower()+'|'+keyword[0].upper()+')'+keyword[1:]+'(?:\w|\ )*?===\n)((?:.|\n)*?)(?:(?:===|==)(?:\w|\ )*(?:===|==)\n)'
    for i in range(len(search_list)):
             
        page =wikipedia.page(search_list[i], auto_suggest = False)
        page_title =page.title #give the clean name of the page
        page_url=page.url #give the url of the page
        site = pywikibot.Site("en", "wikipedia")
        page = pywikibot.Page(site, page_title)
        if keyword.lower() in page_title.lower(): 
            page_text=page.text
        else:
            page_text = str(re.findall(recode , page.text))
        if page_text=="[]":
            page_text = str(re.findall(recode2, page.text))
            
        infopage ={'Name only' : page_title, 'page url' :page_url,'text':page_text}
        tableau.append(infopage)
    df=pd.DataFrame.from_dict(tableau)
    return df


df=crea_dataframe(search_list,"climate change")
df
# Out:
# Wall time: 4.42 s
#                       Name only  \
# 0     Effects of climate change
# 1                Climate change
# 2                Bird migration
# 3     Climate change in Alabama
# 4  Climate change in California
# 5     Climate change in Arizona
#
#                                             page url  \
# 0  https://en.wikipedia.org/wiki/Effects_of_clima...
# 1       https://en.wikipedia.org/wiki/Climate_change
# 2       https://en.wikipedia.org/wiki/Bird_migration
# 3  https://en.wikipedia.org/wiki/Climate_change_i...
# 4  https://en.wikipedia.org/wiki/Climate_change_i...
# 5  https://en.wikipedia.org/wiki/Climate_change_i...
#
#                                                 text
# 0  {{short description|Effects created by climate...
# 1  {{Short description|Current rise in Earth's av...
# 2  ['Large scale [[global warming|climatic change...
# 3  {{Short description|Climate change in the US s...
# 4  {{Short description|Climate change in the US s...
# 5  {{Short description|Climate change in the US s...

# %% [markdown]
# #### extract from text document the wiki code

# %%
# %load '2008.txt'
def text_import(year : int):
    
    filename =str(year) +".txt"
    dataframe_name = pd.read_csv(filename, sep = '\t')
    print(type(dataframe_name))
    return str(dataframe_name)

# %%
 #creation of a list that will contain a dictionnary for each page with the information
for i in range(2006,2022):
    page =wikipedia.page(search_list[0], auto_suggest = False)
    page_title =i #give the clean name of the page
    page_url= "https://en.wikipedia.org/w/index.php?title=Effects_of_climate_change&oldid=298597212" #give the url of the page
    text=text_import(str(i))
    infopage ={'Name only' : page_title, 'page url' :page_url,'text':text}
    tableau.append(infopage)
    df=pd.DataFrame.from_dict(tableau)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14272/99880496.py in <module>
#       1 #creation of a list that will contain a dictionnary for each page with the information
#       2 for i in range(2006,2022):
# ----> 3    page =wikipedia.page(search_list[0], auto_suggest = False)
#       4    page_title =i #give the clean name of the page
#       5    page_url= "https://en.wikipedia.org/w/index.php?title=Effects_of_climate_change&oldid=298597212" #give the url of the page
#
# NameError: name 'search_list' is not defined

# %%
df["text"]
# Out:
# 0    []
# Name: text, dtype: object

# %% [markdown]
# ## Get the citations

# %%
print('Getting citations')
df['citations'] = df['text'].progress_apply(lambda x: get_citations(x))

print("getting the number of references")
df['Ref count'] = df['citations'].progress_apply(lambda x: x['Ref count'])

print("getting the number of scientific citations")
df['nb_journal_citations'] = df['citations'].progress_apply(lambda x: x['nb_journal_citations'])
df["journalcitation"] = df['citations'].progress_apply(lambda x: x['citationjournal'])

print("getting the number of .org citation")
df["citation org"]=df['citations'].progress_apply(lambda x: x['citations.org'])
df["citationorgtext"]=df['citations'].progress_apply(lambda x: x["citationorgtext"])

print("getting the number of .gov citation")
df["citation gov"]=df['citations'].progress_apply(lambda x: x["citations.gov"])
df["citationgovtext"]=df['citations'].progress_apply(lambda x: x["citationgovtext"])

print("getting the number of IPCC citation")
df["citation IPCC"]=df['citations'].progress_apply(lambda x: x["citationsIPCC.ch"])

print("getting the .com citations")
df["citation com"]=df['citations'].progress_apply(lambda x: x["citations.com"])
df["citationcomtext"]=df['citations'].progress_apply(lambda x: x["citationcomtext"])

print("getting the ipbes citation")
df["citationipbes"]=df['citations'].progress_apply(lambda x: x["citationsipbes"])

print("getting the guardian citation")
df["citationguardian"]=df['citations'].progress_apply(lambda x: x["citationguardian"])

print("getting the other citation")
df["citationautre"]=df['citations'].progress_apply(lambda x: x["citationautre"])

df["org count"]=df["citation org"]/df["Ref count"]
df["gov count"]=df["citation gov"]/df["Ref count"]
df["com count"]=df["citation com"]/df["Ref count"]
df["Sci count"]=df['nb_journal_citations']/df['Ref count']
df['IPCC count']=df['citation IPCC']/df['Ref count']
df['percentage of official sources']=(df['nb_journal_citations']+ df['citation gov']+ df['citation org']+df['citation IPCC']+df['citationipbes'])/df['Ref count']


print('Done!')
df.head()
# Out:
# Getting citations
#  33%|████████████████████████████                                                        | 2/6 [00:00<00:00, 12.50it/s]
#                                                    ref
# 26   environmental migrants: up to 1 billion by 205...
# 51   {{cite news |date=5 may 2020 |title=climate ch...
# 68         {{cite book|title=in {{harvnb|usgcrp|2017}}
# 78   [https://crowtherlab.pageflow.io/cities-of-the...
# 84   {{cite web |title=climate change: evidence and...
# 106  un-water (2013) [https://collections.unu.edu/e...
# 108  {{cite journal\n | last=tsosie | first=rebecca...
# 112      {{cite web|title=thermodynamics: albedo {{!}}
# 133  {{cite web\n | pages=3–4\n | last1=hansen | fi...
# 150  [https://serc.carleton.edu/eslabs/cryosphere/1...
# 176  {{cite web |title=who &#124; the global burden...
# 201  [https://www.climateforesight.eu/migrations/en...
# 213  {{cite web |title=motion for a resolution on t...
# 233  {{cite news |ref={{harvid|world resources inst...
# 255  {{cite book|last1=kennedy|first1=john|url=http...
#  67%|████████████████████████████████████████████████████████                            | 4/6 [00:00<00:00, 14.17it/s]
#                                                    ref
# 2    {{cite news |ref={{harvid|salon, 25 september|...
# 3                     {{harvnb|oxford languages|2019}}
# 5    {{harvnb|dessai|2001|p=4}}; {{harvnb|grubb|200...
# 9    {{cite book\n |last1=dunlap |first1=riley e.\n...
# 10        {{harvnb|ruseva|hedrick|marland|tovar|2020}}
# ..                                                 ...
# 595       {{harvnb|cohen|screen|furtado|barlow|2014}}.
# 596  {{harvnb|united nations environment programme|...
# 597                  {{harvnb|teske|2019|pp=409–410}}.
# 602         {{harvnb|doney|fabry|feely|kleypas|2009}}.
# 603  {{cite web |ref={{harvid|natural resources def...
#
# [268 rows x 1 columns]
# Empty DataFrame
# Columns: [ref]
# Index: []
# Empty DataFrame
# Columns: [ref]
# Index: []
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 14.07it/s]
#                                                   ref
# 1   {{cite web|url=http://droughtmonitor.unl.edu/|...
# 12  ala (american lung association). 2008. state o...
# 22  {{cite news |last1=blaauw |first1=maddie |titl...
# 37  knowlton, k., m. rotkin-ellman, g. king, h. g....
# 40  {{cite web|url=http://newsroom.haas.berkeley.e...
# 45  {{cite web|title=on the causal link between ca...
# 48  california agriculture statistical review. sac...
# Empty DataFrame
# Columns: [ref]
# Index: []
# getting the number of references
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# getting the number of scientific citations
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1499.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1497.52it/s]
# getting the number of .org citation
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# getting the number of .gov citation
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1499.84it/s]
# getting the number of IPCC citation
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# getting the .com citations
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 5400.39it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# getting the ipbes citation
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1498.32it/s]
# getting the guardian citation
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# getting the other citation
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1497.97it/s]
# Done!
#                       Name only  \
# 0     Effects of climate change
# 1                Climate change
# 2                Bird migration
# 3     Climate change in Alabama
# 4  Climate change in California
#
#                                             page url  \
# 0  https://en.wikipedia.org/wiki/Effects_of_clima...
# 1       https://en.wikipedia.org/wiki/Climate_change
# 2       https://en.wikipedia.org/wiki/Bird_migration
# 3  https://en.wikipedia.org/wiki/Climate_change_i...
# 4  https://en.wikipedia.org/wiki/Climate_change_i...
#
#                                                 text  \
# 0  {{short description|Effects created by climate...
# 1  {{Short description|Current rise in Earth's av...
# 2  ['Large scale [[global warming|climatic change...
# 3  {{Short description|Climate change in the US s...
# 4  {{Short description|Climate change in the US s...
#
#                                            citations  Ref count  \
# 0  {'Ref count': 252, 'nb_journal_citations': 57,...        252
# 1  {'Ref count': 603, 'nb_journal_citations': 114...        603
# 2  {'Ref count': 5, 'nb_journal_citations': 4, 'c...          5
# 3  {'Ref count': 8, 'nb_journal_citations': 0, 'c...          8
# 4  {'Ref count': 52, 'nb_journal_citations': 9, '...         52
#
#    nb_journal_citations                                    journalcitation  \
# 0                    57  [10.1073/pnas.1003292107, 10.1016/j.egycc.2020...
# 1                   114  [10.1596/978-1-4648-0673-5, 10.1126/science.12...
# 2                     4  [10.1038/nature04539, 10.1111/conl.12386, 10.1...
# 3                     0                                                 []
# 4                     9  [10.1073/pnas.0404500101, 10.1073/pnas.1617464...
#
#    citation org                                    citationorgtext  \
# 0            28  [news.un.org, openknowledge.worldbank.org, www...
# 1            28  [www.fao.org, ourworldindata.org, www.unenviro...
# 2             1                                    [www.panda.org]
# 3             0                                                 []
# 4            10  [phys.org, rprogress.org, www.nrdc.org, inside...
#
#    citation gov  ...                                    citationcomtext  \
# 0            24  ...  [www.britannica.com, airportbusiness.com, www....
# 1            16  ...  [books.google.com, books.google.com, link.spri...
# 2             0  ...                                                 []
# 3             1  ...  [www.alreporter.com, www.montgomeryadvertiser....
# 4             9  ...  [www.reuters.com, www.nytimes.com, www.ecowatc...
#
#    citationipbes  citationguardian  \
# 0              2                10
# 1              0                15
# 2              0                 0
# 3              0                 0
# 4              0                 1
#
#                                        citationautre  org count  gov count  \
# 0  [environmental migrants: up to 1 billion by 20...   0.111111   0.095238
# 1  [{{cite news |ref={{harvid|salon, 25 september...   0.046434   0.026534
# 2                                                 []   0.200000   0.000000
# 3                                                 []   0.000000   0.125000
# 4  [{{cite web|url=http://droughtmonitor.unl.edu/...   0.192308   0.173077
#
#   com count  Sci count  IPCC count  percentage of official sources
# 0  0.091270   0.226190    0.376984                        0.817460
# 1  0.013267   0.189055    0.255390                        0.517413
# 2  0.000000   0.800000    0.000000                        1.000000
# 3  0.875000   0.000000    0.000000                        0.125000
# 4  0.269231   0.173077    0.038462                        0.576923
#
# [5 rows x 23 columns]

# %%
df.loc[:,["Name only","Ref count","citation IPCC","percentage of official sources","IPCC count","citationipbes","citationguardian"]]
# Out:
#                       Name only  Ref count  citation IPCC  \
# 0     Effects of climate change        252             95
# 1                Climate change        603            154
# 2                Bird migration          5              0
# 3     Climate change in Alabama          8              0
# 4  Climate change in California         52              2
# 5     Climate change in Arizona          5              0
#
#    percentage of official sources  IPCC count  citationipbes  citationguardian
# 0                        0.817460    0.376984              2                10
# 1                        0.517413    0.255390              0                15
# 2                        1.000000    0.000000              0                 0
# 3                        0.125000    0.000000              0                 0
# 4                        0.576923    0.038462              0                 1
# 5                        0.800000    0.000000              0                 0

# %% [markdown]
# ## Creation of Dataframes containing the name of the most cited pages

# %%
def creadicorg(name_cit : str ,dicorg : dict):
    '''
    and the citation name_cit to the dictionnary dicorg
    
    param name_cit: the name of the citation in the form of a string
    param dicorg: a dictionnary containing the name and number of citation already found is updated thanks to this funciton
    return dicorg
    '''

    if "www." in name_cit:
        name_cit=name_cit.replace('www.','')
    if name_cit in dicorg:
        dicorg[name_cit]+=1
    else:
        dicorg[name_cit]=1
    
    return dicorg

# %%
def sortcitation(d):
    '''
    param d: a column of a dataframe containing the text of the citation
    
    return dico: a dictionnary  the name of the site of interest and the numbers of time it is found in d. 
    return dforg : a dataframe containing the name of the site of interest and the numbers of time it's found in descending order. 
    '''
    dicorg={}
    for liste_cit in d:
        #if the list is empty there is no need to extract
        if liste_cit!= []:
            if type(liste_cit)==type("r"):
                dicorg=creadicorg(liste_cit,dicorg)
                
            if type(liste_cit)==list:
                if type(liste_cit[0])==type("r"):
                    for i in liste_cit:
                        dicorg=creadicorg(i,dicorg)
                else :
                    for i in liste_cit:
                        name_cit=i[0]
                        dicorg=creadicorg(name_cit,dicorg)

    dico=dicorg
    #with all dictionary keys with values.
    dforg=pd.DataFrame(list(dicorg.items()),columns=['name of site','numbertimescited'])
    dforg.sort_values(by=['numbertimescited'], inplace=True, ascending=False)
    return dforg,dico

# %%
dforg,dico=sortcitation(df.loc[:,"citationorgtext"])
sns.set(font_scale=3)
sns.set_color_codes("pastel")
sns.barplot(x="numbertimescited", y="name of site", data=dforg, color="pink",orient = 'h')
sns.despine(left=True, bottom=True)
sns.set(font_scale=4)
plt.title("number of times the sites are cited")
plt.gcf().set_size_inches(50,50)

# %%
dfgov,j=sortcitation(df.loc[:,"citationgovtext"])
dfgov
# Out:
#                      name of site  numbertimescited
# 13               climate.nasa.gov                 5
# 20  19january2017snapshot.epa.gov                 4
# 7       earthobservatory.nasa.gov                 3
# 23                  energy.ca.gov                 3
# 18                        epa.gov                 3
# 1                     climate.gov                 3
# 0                   ncdc.noaa.gov                 3
# 2    science2017.globalchange.gov                 3
# 9                 arctic.noaa.gov                 2
# 10                       nasa.gov                 2
# 11          climatewatch.noaa.gov                 2
# 12                  gfdl.noaa.gov                 2
# 15          oceanservice.noaa.gov                 2
# 8              climatescience.gov                 2
# 22                    fire.ca.gov                 2
# 6                   pubs.usgs.gov                 1
# 3      downloads.globalchange.gov                 1
# 24                     arb.ca.gov                 1
# 21               globalchange.gov                 1
# 16                        nps.gov                 1
# 19                   sos.noaa.gov                 1
# 4                   giss.nasa.gov                 1
# 17             data.giss.nasa.gov                 1
# 14                       nifc.gov                 1
# 5              www1.ncdc.noaa.gov                 1
# 25                   cpo.noaa.gov                 1

# %%
dcom,bl=sortcitation(df.loc[:,"citationcomtext"])
dcom
# Out:
#                  name of site  numbertimescited
# 22           books.google.com                 8
# 11                latimes.com                 4
# 5                 nytimes.com                 3
# 19                    bbc.com                 2
# 3                ecowatch.com                 2
# 9      scientificamerican.com                 2
# 27                    cnn.com                 2
# 28             kansascity.com                 1
# 23          link.springer.com                 1
# 24             alreporter.com                 1
# 25   montgomeryadvertiser.com                 1
# 26                     al.com                 1
# 0              britannica.com                 1
# 29            theatlantic.com                 1
# 21               scienmag.com                 1
# 31                gizmodo.com                 1
# 32                 medium.com                 1
# 33         mavensnotebook.com                 1
# 34                foxnews.com                 1
# 35              economist.com                 1
# 30                reuters.com                 1
# 18                 apnews.com                 1
# 20            livescience.com                 1
# 1         airportbusiness.com                 1
# 17         smithsonianmag.com                 1
# 16         washingtonpost.com                 1
# 15            edition.cnn.com                 1
# 14            marketwatch.com                 1
# 13                   time.com                 1
# 12           academic.oup.com                 1
# 10           triplepundit.com                 1
# 8      nationalgeographic.com                 1
# 7   internationaldirector.com                 1
# 6                  nature.com                 1
# 4                      dw.com                 1
# 2              maplecroft.com                 1
# 36              azcentral.com                 1

# %% [markdown]
# ## Evolution of the citation (To do only if the wikicode of old versions have been scrapped)

# %% [markdown]
# #### Plot of the evoltuion of the citations

# %%
df.loc[0,["Name only"]]=2022
df.set_index("Name only",inplace=True)

# %%
sns.lineplot(data=[df["nb_journal_citations"],df["citation IPCC"],df["Ref count"],df["citation org"],df["citation com"], df["citation gov"]]).set(title='evolution of citation',xlabel='year',ylabel='number of citation')
plt.savefig('evolution of citation.png')

# %%
sns.set(rc = {'figure.figsize':(17,8)})
sns.lineplot(data=[df["Sci count"],df["IPCC count"],df['percentage of official sources'],df["org count"],df["gov count"],df["com count"]]).set(title='evolution of citation',xlabel='year',ylabel='number of citation')

plt.savefig('rate evolution of citation.png')

# %% [markdown]
# #### dataframe containing the name of the evolution of the citation

# %%
def crea_df_evolution_citation(df, end_cit :str):  
    '''
    creation of a dataframe containing the number of a name of a citation finishing by name_cit (exemple org) for each year
    
    param df : the df containing the information the citation for an article and it's past
    param end_cit : the type of citation we want to extract it can be either .org, .com or .gov citations
    
    return dorg: a dataframe with axis the year and the name of the citation 
    '''
    columntext="citation"+end_cit+"text"
    columnnumber= "citation "+end_cit
    dorg=pd.DataFrame()

    for i in range(2007,2022):
        if int(df.loc[i,columnnumber])!=0:
            dforg,dicorg=sortcitation(df.loc[i,columntext])
            for j in dicorg.keys():
                dorg.loc[i,[j]]= dicorg[j]

    dorg=dorg.fillna(0)            

    dorg.loc["total",:]=dorg.sum(0)
    dorg["somme"]=dorg.sum(1)
    #new_df = dorg.loc[:, dorg.loc["total"]>1]
    #dorg = new_df.drop('total')
    return dorg

crea_df_evolution_citation(df,"org")
crea_df_evolution_citation(df,"gov")
crea_df_evolution_citation(df,"com")
#plol_evol_cit(df.loc[i,["citationorg"]],df.loc[i,["citationorgtext"]])
dorg.to_csv('climatechangehistoricdorg.csv')

# %% [markdown]
# ## Cleaning the column and exporting the data frame and scrap of page information

# %%
titlelist=df["Name only"].tolist() #make a list will all titles
#We need to recreate the wiki url, first step is to get rid of blanks
titleunderscore = [sub.replace(' ', '_') for sub in titlelist]

# %%
#We finally get from the original url to the pageinfo url
urlmodifié = ['https://en.wikipedia.org/w/index.php?title=' + i +'&action=info' for i in titleunderscore]
print(urlmodifié)
# Out:
# ['https://en.wikipedia.org/w/index.php?title=Effects_of_climate_change&action=info', 'https://en.wikipedia.org/w/index.php?title=Climate_change&action=info', 'https://en.wikipedia.org/w/index.php?title=Bird_migration&action=info', 'https://en.wikipedia.org/w/index.php?title=Climate_change_in_Alabama&action=info', 'https://en.wikipedia.org/w/index.php?title=Climate_change_in_California&action=info', 'https://en.wikipedia.org/w/index.php?title=Climate_change_in_Arizona&action=info']

# %%
#Cell to scrap infos from "page info" section (2 to scrap the third table of the page)
doblist=[]
creatorlist=[]
totaledits=[]
recentedits=[]
pageid=[]
pagelenght=[]
editprotection=[]
recentpageviews=[]

for i in tqdm(urlmodifié) :
    source = requests.get(i)
    soup = BeautifulSoup(source.text, 'lxml')
    #soup = BeautifulSoup(source, "html.parser", from_encoding="utf-8")
    alltables=soup.findAll('table', {"class": "wikitable mw-page-info"})
    tableau_html_liste=pd.read_html(str(alltables)) #We get it as a list   
    df_pageinfo2=pd.DataFrame(tableau_html_liste[2]) #And make it a df 
    #The number between brackets corresponds to the number of the table according to its order on the html page
    creatorlist += [df_pageinfo2.iat[0, 1]]
    doblist += [df_pageinfo2.iat[1, 1]]
    totaledits += [df_pageinfo2.iat[4, 1]]
    recentedits += [df_pageinfo2.iat[5, 1]]
    
    
    #Scrap of the first table of the page (0)
    df_pageinfo0=pd.DataFrame(tableau_html_liste[0])
    pagelenght += [df_pageinfo0.iat[2, 1]]
    pageid += [df_pageinfo0.iat[3, 1]]
    #recentpageviews += [df_pageinfo0.loc['Page views in the past 30 days']]
            
    
    #Scrap of the second table of the page (1)
    df_pageinfo1=pd.DataFrame(tableau_html_liste[1])
    editprotection += [df_pageinfo1.iat[1, 1]]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:05<00:00,  1.11it/s]

# %%
#Cell to add the new lists as new columns of the df
df["Page id"]=pageid
df["Edit protection"]=editprotection
df["Page lenght (Bytes)"]=pagelenght
df["DOB"]=doblist
df["Creator"]=creatorlist
df["Total edits"]=totaledits
df["Recent edits"]=recentedits
df.head()
# Out:
#                       Name only  \
# 0     Effects of climate change
# 1                Climate change
# 2                Bird migration
# 3     Climate change in Alabama
# 4  Climate change in California
#
#                                             page url  \
# 0  https://en.wikipedia.org/wiki/Effects_of_clima...
# 1       https://en.wikipedia.org/wiki/Climate_change
# 2       https://en.wikipedia.org/wiki/Bird_migration
# 3  https://en.wikipedia.org/wiki/Climate_change_i...
# 4  https://en.wikipedia.org/wiki/Climate_change_i...
#
#                                                 text  \
# 0  {{short description|Effects created by climate...
# 1  {{Short description|Current rise in Earth's av...
# 2  ['Large scale [[global warming|climatic change...
# 3  {{Short description|Climate change in the US s...
# 4  {{Short description|Climate change in the US s...
#
#                                            citations  Ref count  \
# 0  {'Ref count': 252, 'nb_journal_citations': 57,...        252
# 1  {'Ref count': 603, 'nb_journal_citations': 114...        603
# 2  {'Ref count': 5, 'nb_journal_citations': 4, 'c...          5
# 3  {'Ref count': 8, 'nb_journal_citations': 0, 'c...          8
# 4  {'Ref count': 52, 'nb_journal_citations': 9, '...         52
#
#    nb_journal_citations                                    journalcitation  \
# 0                    57  [10.1073/pnas.1003292107, 10.1016/j.egycc.2020...
# 1                   114  [10.1596/978-1-4648-0673-5, 10.1126/science.12...
# 2                     4  [10.1038/nature04539, 10.1111/conl.12386, 10.1...
# 3                     0                                                 []
# 4                     9  [10.1073/pnas.0404500101, 10.1073/pnas.1617464...
#
#    citation org                                    citationorgtext  \
# 0            28  [news.un.org, openknowledge.worldbank.org, www...
# 1            28  [www.fao.org, ourworldindata.org, www.unenviro...
# 2             1                                    [www.panda.org]
# 3             0                                                 []
# 4            10  [phys.org, rprogress.org, www.nrdc.org, inside...
#
#    citation gov  ...   Page id  \
# 0            24  ...   2119174
# 1            16  ...   5042951
# 2             0  ...    201943
# 3             1  ...  54374960
# 4             9  ...  18159949
#
#                                      Edit protection  Page lenght (Bytes)  \
# 0  Require autoconfirmed or confirmed access (no ...               186247
# 1       Require administrator access (no expiry set)               271827
# 2                    Allow all users (no expiry set)                91540
# 3                    Allow all users (no expiry set)                12299
# 4                    Allow all users (no expiry set)                35848
#
#                       DOB                    Creator  Total edits  \
# 0     15:09, 26 June 2005    Rd232 (talk | contribs)         5537
# 1  17:25, 30 October 2001  Zundark (talk | contribs)        25732
# 2    07:15, 27 March 2003         195.93.32.9 (talk)         1708
# 3     15:09, 23 June 2017   BD2412 (talk | contribs)           72
# 4     10:29, 27 June 2008      Mac (talk | contribs)          446
#
#   Recent edits  Formated DOB  Year_month  Year
# 0           19    2005-06-26     2005-06  2005
# 1           39    2001-10-30     2001-10  2001
# 2            6    2003-03-27     2003-03  2003
# 3            0    2017-06-23     2017-06  2017
# 4            5    2008-06-27     2008-06  2008
#
# [5 rows x 34 columns]

# %%
#Cleaning the table

#Getting rid of the time
df["DOB"]= df["DOB"].str.slice(7,100,1) 
#peutêtre qu'on pourrait mettre comme end point la len de la string

#Format the date
df["Formated DOB"]=pd.to_datetime(df["DOB"], format='%d %B %Y')
df["Year_month"]= pd.to_datetime(df['DOB']).dt.to_period('M')

#Getting the year
df['Year'] = pd.DatetimeIndex(df['DOB']).year

#Cleaning the creator 
df["Creator"]= df["Creator"].str.replace(r"\(.*\)",'', regex=True)

# %% [markdown]
# #### Plot the ratio of page created by a certain editor in our corpus

# %%
#creation of a new dataframe
dfbis=df

dfbis["number of article created by creator"]=1
dfbis.set_index("Creator",inplace=True)
dfbis=dfbis.groupby("Creator")["number of article created by creator"].sum()

fig = plt.figure(0,figsize=(20,15))
dfbis.plot.pie(subplots=True)
fig.savefig('article_created_by_creator.jpg', bbox_inches='tight', dpi=150)

dftris=dfbis[dfbis==1].sum()
dfbis.loc["Other"]=dftris


fig2 = plt.figure(1,figsize=(20,15))
dfbis[dfbis>1].plot.pie(subplots=True)
fig2.savefig('article_created_by_important_creator.jpg', bbox_inches='tight', dpi=150)

plt.show()

# %% [markdown]
# #### plot of the timeline

# %%
fig = plt.figure(0,figsize=(20,15))
plothist=df["Year"].value_counts().sort_index().plot(kind="bar")
fig.savefig('timeline.jpg', bbox_inches='tight', dpi=150)
plt.xlabel('date of birth',fontsize = 20) 
plt.ylabel('number of article',fontsize = 20) 
plt.title("number of article in function of their year of birth",fontsize = 30)
plt.show()

# %% [markdown]
# #### Clean and export the dataframes to csv

# %%
del df['citationorgtext']
del df['citationgovtext']
del df['text']
del df["citations"]
del df["citationcomtext"]

# %%
df.to_csv('climatechange.csv')
dforg.to_csv('climatechangeorg.csv')
dfgov.to_csv('climatechangegov.csv')
dcom.to_csv('climatechangecom.csv')

# %% [markdown]
# #### Next is xtools part, ignore it

# %%
prose_dic=[]
unique_references_xtools=[]
key = "unique_references"
for i in tqdm(urlxtools_prose) :
    prose_str=requests.get(i).text
    prose_dic = json.loads(prose_str)
    unique_references_xtools.append(prose_dic[key])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:03<00:00,  1.76it/s]

# %%
df['unique_references_xtools']=unique_references_xtools

# %%
df.head()
df.to_csv('Corpus_CC_V3.csv')

# %%
for i in urlxtools_edits:
    print(requests.get(i).text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>
#         Error - XTools
#     </title>
#
#         <script type="text/javascript">
#         xtBaseUrl = "/";
#
#                 i18nLang = "en";
#         i18nPaths = {};
#                     i18nPaths["en"] = "/i18n/en.json";
#                     i18nPaths["en"] = "/i18n/en.json";
#
#         i18nRTL = false;
#     </script>
#
#             <script type="text/javascript" src="https://tools-static.wmflabs.org/cdnjs/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
#         <script type="text/javascript" src="/assets/app.b091821e.js"></script>
#         <script type="text/javascript" src="https://tools-static.wmflabs.org/cdnjs/ajax/libs/twitter-bootstrap/3.3.7/js/bootstrap.min.js"></script>
#         <script src="https://tools-static.wmflabs.org/cdnjs/ajax/libs/select2/4.0.5/js/select2.full.min.js"></script>
#                 <link rel="stylesheet" type="text/css" media="screen" href="https://tools-static.wmflabs.org/cdnjs/ajax/libs/twitter-bootstrap/3.3.7/css/bootstrap.min.css">
#         <link rel="stylesheet" type="text/css" media="screen" href="https://tools-static.wmflabs.org/cdnjs/ajax/libs/select2/4.0.5/css/select2.min.css">
#         <link rel="stylesheet" type="text/css" media="screen" href="/assets/app.44ad118c.css">
#
#     <link rel="shortcut icon" sizes="16x16 32x32 48x48 96x96 144x144" href="/images/favicon.ico" />
#     <link rel="apple-touch-icon" sizes="16x16 32x32 48x48 96x96 144x144" href="/images/apple-touch-icon.png" />
#     <link rel="apple-touch-icon-precomposed icon" sizes="16x16 32x32 48x48 96x96 144x144" href="/images/apple-touch-icon-precomposed.png" />
#     <link rel="icon" sizes="196x196" href="/images/apple-touch-icon.png">
#
#     <meta charset="utf-8">
#     <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         </head>
#
# <body class="error" >
# <a class="hidden-link" href="/foo" style="visibility: hidden;"></a>
# <header class="navbar navbar-default navbar-top" role="navigation">
#     <button class="navbar-toggle collapsed pull-left" data-toggle="collapse" data-target=".tool-links" aria-expanded="false">
#       <span class="sr-only">Toggle navigation</span>
#       <span class="icon-bar"></span>
#       <span class="icon-bar"></span>
#       <span class="icon-bar"></span>
#     </button>
#     <ol class="nav-buttons list-inline pull-right">
#
#         <li>
#                     <a class="btn btn-default login-btn" href="https://xtools.wmflabs.org/login?callback=https://xtools.wmflabs.org/oauth_callback?redirect%3Dhttps://xtools.wmflabs.org/api/metrics/edits/per-page/en.wikipedia.org/Climate_change_in_Arizona/all-editor-types/daily/20010101/20220101">
#                 <span class="glyphicon glyphicon-user"></span>
#                 Log in
#             </a>
#                 </li>
#
#     </ol>
#     <nav class="tool-links navbar-collapse collapse">
#         <ol class="tool-links--nav nav navbar-nav navbar-left">
#             <li>
#                 <a class="home-link" href="/">
#                     <img src="/images/logo.svg" alt="Logo" />
#                 </a>
#             </li>
#
#                             <li role="presentation" class="dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                         Edit Counter
#                         <span class="caret"></span>
#                     </a>
#                     <ul class="dropdown-menu">
#                         <li class="tool-links--entry">
#                             <a href="/ec?sections=all">Edit Counter</a>
#                         </li>
#                         <li class="divider" role="separator"></li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/ec-generalstats">General statistics</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/ec-monthcounts">Month counts</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/ec-namespacetotals">Namespace Totals</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/ec-rightschanges">Rights changes</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/ec-timecard">Time card</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/topedits">Top edited pages</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/ec-yearcounts">Year counts</a>
#                             </li>
#                                             </ul>
#                 </li>
#                                         <li role="presentation" class="dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                         User
#                         <span class="caret"></span>
#                     </a>
#                     <ul class="dropdown-menu">
#                                                     <li class="tool-links--entry">
#                                 <a href="/adminscore">Admin Score</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/autoedits">Automated Edits</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/categoryedits">Category Edits</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/ec">Edit Counter</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/editsummary">Edit Summaries</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/globalcontribs">Global Contributions</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/pages">Pages Created</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/sc">Simple Counter</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/topedits">Top Edits</a>
#                             </li>
#                                             </ul>
#                 </li>
#                                         <li role="presentation" class="dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                         Page
#                         <span class="caret"></span>
#                     </a>
#                     <ul class="dropdown-menu">
#                                                     <li class="tool-links--entry">
#                                 <a href="/authorship">Authorship</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/blame">Blame</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/articleinfo">Page History</a>
#                             </li>
#                                             </ul>
#                 </li>
#                                         <li role="presentation" class="dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                         Project
#                         <span class="caret"></span>
#                     </a>
#                     <ul class="dropdown-menu">
#                                                     <li class="tool-links--entry">
#                                 <a href="/adminstats">Admin Stats</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/patrollerstats">Patroller Stats</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/stewardstats">Steward Stats</a>
#                             </li>
#                                                     <li class="tool-links--entry">
#                                 <a href="/largestpages">Largest Pages</a>
#                             </li>
#                                             </ul>
#                 </li>
#
#                         <li class="tool-links--more dropdown hidden">
#                 <a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false">
#                     More
#                     <span class="caret"></span>
#                 </a>
#                 <ul class="dropdown-menu"></ul>
#             </li>
#         </ol>
#     </nav>
# </header>
#
# <div class="site-notice">
#
#
#         </div>
#
# <div id="wrapper">
# <main id="content" class="clearfix">
#         <div class="col-lg-8 col-lg-offset-2">
#             </div>
#
#     <div class="panel panel-danger">
#     <header class="panel-heading">
#         <div class="text-center xt-heading-top">
#             <strong>404: Not Found</strong>
#         </div>
#     </header>
#
#     <div class="panel-body xt-panel-body error-wrapper">
#         <div class="error-mascot--wrapper pull-right">
#             <a target="_blank" title="By Lilyu (Own work) [WTFPL], via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File%3ALapinou_Furieux.svg"><img class="error-mascot" alt="Lapinou Furieux" src="/images/error_mascot.svg"/></a>
#         </div>
#
#
#                                 <p>A fatal error has occurred within XTools. This has been automatically reported, but feel free to file a task on                 <a target="_blank" href="https://phabricator.wikimedia.org/maniphest/task/create/?title=PLEASE REPLACE WITH A DESCRIPTION OF THE ERROR&amp;priority=75&amp;projects=XTools&amp;description=```/var/www/vendor/symfony/symfony/src/Symfony/Component/HttpKernel/EventListener/RouterListener.php: 136 - No route found for &quot;GET /api/metrics/edits/per-page/en.wikipedia.org/Climate_change_in_Arizona/all-editor-types/daily/20010101/20220101&quot;```%0A%0AURL: https://xtools.wmflabs.org/api/metrics/edits/per-page/en.wikipedia.org/Climate_change_in_Arizona/all-editor-types/daily/20010101/20220101%0A%0APlease provide any further details here%0A%0AXTools version: 3.15.0-fd260c37">Phabricator</a>
#              (requires a Wikimedia account).</p>
#
#                                     <p>The server said: <code>No route found for "GET /api/metrics/edits/per-page/en.wikipedia.org/Climate_change_in_Arizona/all-editor-types/daily/20010101/20220101"</code></p>
#
#
#         <div class="text-center">
#             <img class="splash-logo splash-logo--small" style="width:150px" src="/images/logo.svg" alt="XTools" />
#             <h5 class="about-subtitle">
#                 Version 3.15.0
#                 (2022-03-16)
#                 &middot;
#                 <a target="_blank" href="https://www.mediawiki.org/wiki/Special:MyLanguage/XTools">Documentation</a>
#                 &middot;
#                     <a target="_blank" href="https://www.mediawiki.org/wiki/Special:MyLanguage/XTools/API">API</a>
#
#                 &middot;
#                 <a target="_blank" href="https://github.com/x-tools/xtools">View Source</a>
#             </h5>
#             <small>
#                 <a target="_blank" href="https://www.mediawiki.org/wiki/Talk:XTools">Feedback</a>
# &middot;
# <a href='https://phabricator.wikimedia.org/maniphest/task/create/?title=PLEASE REPLACE WITH A DESCRIPTION OF THE ISSUE&amp;projects=XTools&amp;description=Please provide any further details here%0A%0AXTools version: 3.15.0-fd260c37' target=_blank>Report an issue</a>
# &middot;
# <a href="ircs://irc.libera.chat:6697/#wikimedia-xtools" target="_blank">#wikimedia-xtools</a>
# <sup><a style="color:green" href="https://kiwiirc.com/nextclient/irc.libera.chat/#wikimedia-xtools" target="_blank">connect</a></sup>
#             </small>
#         </div>
#     </div>
# </div>
# </main>
# </div>
#
# <footer class="app-footer container-fluid">
#     <span>
#         <small>
#             <span>Executed in 0.043 seconds.</span> &middot;
#             <span>Taken 2.31 megabytes of memory to execute.</span>
#         </small>
#     </span>
#     <hr>
#     <div class="footer-content">
#         <div class="pull-right footer-branding">
#             <a style="margin-right:5px;" href="//translatewiki.net/?setlang=en "><img height="36px" src="//upload.wikimedia.org/wikipedia/commons/5/51/Translatewiki.net_logo.svg" alt="translatewiki.net logo"/></a>
#                         <a href="https://wikitech.wikimedia.org/wiki/Portal:Cloud_VPS" target="_blank"><img height="40px" src="/images/VPS-badge.svg" alt="Powered by Wikimedia Cloud Services" /></a>
#                     </div>
#         <div class="footer-about">
#             <span>
#                                 &copy; 2008-2022
#                 &middot;
#                 <a href="https://github.com/x-tools/xtools/releases/tag/3.15.0" target="_blank" title="Current XTools version">v.3.15.0</a>
#                 (<a href="https://github.com/x-tools/xtools/tree/fd260c37c5dba0b0f59837179c818697b15f61dc" target="_blank" title="Current code revision">r.fd260c37</a>)
#                 &middot;
#                     <a target="_blank" href="https://www.mediawiki.org/wiki/Special:MyLanguage/XTools/API">API</a>
#
#                 &middot;
#                 <a target="_blank" href="https://www.mediawiki.org/wiki/XTools">Documentation</a>
#                 &middot;
#                 <a target="_blank" href="https://www.mediawiki.org/wiki/Talk:XTools">Feedback</a>
# &middot;
# <a href='https://phabricator.wikimedia.org/maniphest/task/create/?title=PLEASE REPLACE WITH A DESCRIPTION OF THE ISSUE&amp;projects=XTools&amp;description=Please provide any further details here%0A%0AXTools version: 3.15.0-fd260c37' target=_blank>Report an issue</a>
# &middot;
# <a href="ircs://irc.libera.chat:6697/#wikimedia-xtools" target="_blank">#wikimedia-xtools</a>
# <sup><a style="color:green" href="https://kiwiirc.com/nextclient/irc.libera.chat/#wikimedia-xtools" target="_blank">connect</a></sup>
#             </span>
#                                                 <div>Translations powered by <a href='https://translatewiki.net'>translatewiki.net</a>, <a href='https://intuition.toolforge.org/#tab-about'>Intuition</a> and <a href='https://github.com/wikimedia/jquery.i18n'>jQuery.i18n</a>.</div>
#             <small class="footer-quote text-muted">&lt;binasher&gt; it might have worked if i escaped the $ but ghetto backticks work there for sure</small>
#         </div>
#     </div>
# </footer>
# </body>
# </html>

# %% [markdown]
# Trying to extract for weird formatted type but only one in our corpus => not necessary to do a program

# %%
for i in df["Ref count"]:
    if i==0:
        
            page = wikipedia.page(df.loc[i, "Name only"])
            print(df.loc[i, "Name only"])
            
            soup = BeautifulSoup(page.html(), 'html.parser')
            citations =soup.find_all('cite', {'class':"citation cs2"})
            for c in citations:
                test= get_ids_from_ref(str(c))

# %%
df
# Out:
#                                           Name only  \
# 0                         Effects of climate change
# 1                 History of climate change science
# 2                                    Climate change
# 3   Effects of climate change on plant biodiversity
# 4                           Climate change feedback
# 5  Effects of climate change on terrestrial animals
# 6               Effects of climate change on oceans
# 7              Attribution of recent climate change
# 8                       Human impact on marine life
# 9                                    Bird migration
#
#                                             page url  \
# 0  https://en.wikipedia.org/wiki/Effects_of_clima...
# 1  https://en.wikipedia.org/wiki/History_of_clima...
# 2       https://en.wikipedia.org/wiki/Climate_change
# 3  https://en.wikipedia.org/wiki/Effects_of_clima...
# 4  https://en.wikipedia.org/wiki/Climate_change_f...
# 5  https://en.wikipedia.org/wiki/Effects_of_clima...
# 6  https://en.wikipedia.org/wiki/Effects_of_clima...
# 7  https://en.wikipedia.org/wiki/Attribution_of_r...
# 8  https://en.wikipedia.org/wiki/Human_impact_on_...
# 9       https://en.wikipedia.org/wiki/Bird_migration
#
#                                                 text  \
# 0  {{short description|Effects created by climate...
# 1  {{short description|Aspect of the history of s...
# 2  {{Short description|Current rise in Earth's av...
# 3  [[File:Alpine flora logan pass.jpg|380px|thumb...
# 4  {{short description|Feedback related to climat...
# 5  {{Multiple issues|\n{{cleanup reorganize|date=...
# 6  {{Short description|Effects of climate change ...
# 7  {{pp-semi-indef}}\n{{Use dmy dates|date=Decemb...
# 8  {{Short description|none}}\n{{Lead too short|d...
# 9  {{Short description|Seasonal movement of birds...
#
#                                            citations  Ref count  \
# 0  {'Ref count': 252, 'nb_journal_citations': 57,...        252
# 1  {'Ref count': 91, 'nb_journal_citations': 28, ...         91
# 2  {'Ref count': 603, 'nb_journal_citations': 114...        603
# 3  {'Ref count': 60, 'nb_journal_citations': 41, ...         60
# 4  {'Ref count': 103, 'nb_journal_citations': 45,...        103
# 5  {'Ref count': 67, 'nb_journal_citations': 47, ...         67
# 6  {'Ref count': 121, 'nb_journal_citations': 64,...        121
# 7  {'Ref count': 112, 'nb_journal_citations': 21,...        112
# 8  {'Ref count': 143, 'nb_journal_citations': 60,...        143
# 9  {'Ref count': 149, 'nb_journal_citations': 76,...        149
#
#    nb_journal_citations                                    journalcitation  \
# 0                    57  [10.1007/s10584-014-1084-5, 10.1016/j.geoforum...
# 1                    28  [10.1007/bf00139058, 10.1175/1520-0469(1967)02...
# 2                   114  [10.1038/nclimate2979, 10.1002/2017rg000559, 1...
# 3                    41  [10.1007/s10113-015-0870-6, 10.1016/j.tplants....
# 4                    45  [10.1038/s41558-018-0344-1, 10.1029/gb002i003p...
# 5                    47  [10.1175/1520-0477(2000)081<0413:aittie>2.3.co...
# 6                    64  [10.1175/jcli-d-20-0366.1, 10.1017/s0030605307...
# 7                    21  [10.1038/nature05718, 10.1093/ijpor/edr033, 10...
# 8                    60  [10.1038/s41467-019-11394-4, 10.5194/bg-13-176...
# 9                    76  [10.1111/j.0908-8857.2004.03112.x, 10.1371/jou...
#
#    citation org                                    citationorgtext  \
# 0            27  [[www.ucsusa.org], [openknowledge.worldbank.or...
# 1            20  [[history.aip.org], [www.nobelprize.org], [www...
# 2            28  [[www.carbonbrief.org], [www.un.org], [ourworl...
# 3             3  [[archive.org], [www.millenniumassessment.org]...
# 4            10  [[www.iucn.org], [climateprogress.org], [www.n...
# 5             4  [[www.pbs.org], [www.iucn.org], [cwf-fcf.org],...
# 6            14  [[www.sciencemag.org], [worldcat.org], [www.re...
# 7            12  [[www.virtualcentre.org], [americasclimatechoi...
# 8            20  [[oceana.org], [royalsociety.org], [www.pewtru...
# 9            18  [[www.panda.org], [www.birdlife.org], [www.ope...
#
#    citation gov  ...                                    citationcomtext  \
# 0            23  ...  [[academic.oup.com], [www.nationalgeographic.c...
# 1             4  ...  [[books.google.com], [books.google.com], [www....
# 2            16  ...  [[books.google.com], [books.google.com], [book...
# 3             3  ...                                 [[justenergy.com]]
# 4            11  ...  [[www.upi.com], [books.google.com], [www.washi...
# 5             1  ...  [[softbacktravel.com], [theconversation.com], ...
# 6             3  ...  [[www.ecowatch.com], [www.sciencedaily.com], [...
# 7            23  ...  [[www.ecowatch.com], [www.ecowatch.com], [spac...
# 8            11  ...  [[www.youtube.com], [agupubs.onlinelibrary.wil...
# 9             3  ...  [[about.com, birding.about.com], [www.surfbird...
#
#    citationipbes citationguardian  \
# 0              2               10
# 1              0                2
# 2              0               15
# 3              0                0
# 4              0                6
# 5              0                0
# 6              0                1
# 7              0                0
# 8              0                4
# 9              0                0
#
#                                        citationautre org count  gov count  \
# 0  [{{cite web |title=motion for a resolution on ...  0.107143   0.091270
# 1  [john p. holdren: "global thermal pollution", ...  0.219780   0.043956
# 2  [{{cite web\n |title=the climate regime from t...  0.046434   0.026534
# 3  [{{cite conference |author=mackey, b. |title=c...  0.050000   0.050000
# 4  [{{cite web |url=http://geotest.tamu.edu/userf...  0.097087   0.106796
# 5  [mitchell, d., fuller, a., hetem, r. s., & mal...  0.059701   0.014925
# 6  [usgs world energy assessment team, 2000. us g...  0.115702   0.024793
# 7  [{{harvnb|karl|others|2009}}, p. 20., {{harvnb...  0.107143   0.205357
# 8  [{{cite web |url=http://www.cicero.uio.no/webn...  0.139860   0.076923
# 9  [[http://www.zoologie.uni-rostock.de/fileadmin...  0.120805   0.020134
#
#    com count Sci count  IPCC count  percentage of official sources
# 0   0.091270  0.226190    0.376984                        0.809524
# 1   0.109890  0.307692    0.010989                        0.582418
# 2   0.013267  0.189055    0.255390                        0.517413
# 3   0.016667  0.683333    0.000000                        0.783333
# 4   0.077670  0.436893    0.077670                        0.718447
# 5   0.119403  0.701493    0.014925                        0.791045
# 6   0.074380  0.528926    0.074380                        0.743802
# 7   0.080357  0.187500    0.232143                        0.732143
# 8   0.118881  0.419580    0.041958                        0.678322
# 9   0.040268  0.510067    0.000000                        0.651007
#
# [10 rows x 24 columns]
